# %%
# IMAGE PROCESSING

# %%
### LIBRARY THAT CAN BE USED FOR IMAGE PROCESSING
# 1.matplotlib.image
# 2.pillow
# 3.opencv(cv2)

# %%
# 1. Using matplotlib
import matplotlib.image as mpimg
import matplotlib.pyplot as plt

# %%
## loading image
img=mpimg.imread('puppy-care-guide-for-new-parents.jpg')
type(img)
# Out:
# numpy.ndarray

# %%
img.shape
# Out:
# (1365, 2048, 3)

# %%
## display the image
img_plot=plt.imshow(img)
plt.show()

# %%
plt.imshow(img, cmap="hot")
plt.show()

# %%
R, G, B = img[:,:,0], img[:,:,1], img[:,:,2]
imgGray = 0.2989 * R + 0.5870 * G + 0.1140 * B
# plt.imshow(imgGray, cmap='gray')
plt.imshow(imgGray)
plt.show()

# %%
# 2.PILLOW LIBRARY
from PIL import Image

img=Image.open('puppy-care-guide-for-new-parents.jpg')
img.mode
# Out:
# 'RGB'

# %%
print(img.size)
# Out:
# (2048, 1365)

# %%
r_img=img.resize((100,100))
print(r_img.size)
# Out:
# (100, 100)

# %%
r_img.save('dog_image_resized.jpg')

# %%
from PIL import ImageOps
og_image = Image.open("puppy-care-guide-for-new-parents.jpg")
gray_image=ImageOps.grayscale(og_image)

# %%
cv2.imwrite('abc.jpg')

# %%
# 3. OpenCV

# %%
import cv2

img=cv2.imread('puppy-care-guide-for-new-parents.jpg')
type(img)
# Out:
# numpy.ndarray

# %%
img.shape
# Out:
# (1365, 2048, 3)

# %%
grayscale_img=cv2.cvtColor(img,cv2.COLOR_RGB2GRAY)

# %%
type(grayscale_img)
# Out:
# numpy.ndarray

# %%
grayscale_img.save('xyz.jpg')
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-36-27e00e8844ab> in <module>
# ----> 1 grayscale_img.save('xyz.jpg')
#
# AttributeError: 'numpy.ndarray' object has no attribute 'save'
